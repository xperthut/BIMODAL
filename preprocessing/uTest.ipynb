# %%
import torch
import numpy as np
import pandas as pd
from main_preprocessor import preprocess_data
import warnings
warnings.filterwarnings('ignore')

# %%
d = pd.read_csv('../data/getter_smiles_KP_V2.csv', header=None).values.tolist()
l=[]
for x in d:
    l.append(len(x[0]))
    print(len(x[0]), x[0])
l
# Out:
# 56 C1=CC=C(C=C1)C2=CC=C(C=C2)C#CC#CC3=CC=C(C=C3)C4=CC=CC=C4
# 34 C1=CC=C(C=C1)CCC#CC#CCCC2=CC=CC=C2
# 43 C1=CC=C(C=C1)C#CC2=CC=C(C=C2)C#CC3=CC=CC=C3
# 40 C1=C(C(=CC=C1C#CC#CC2=CC=C(C(=C2)C)C)C)C
# 38 C1=CC(=CC=C1CCC#CC#CCCC2=CC=C(C=C2)C)C
# 44 C1(=CC(=CC(=C1C#CC#CC2=C(C=C(C=C2C)C)C)C)C)C
# 73 CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC=CC=C(C)C=CC=C(C)C=CC2=C(CCCC2(C)C)C)C)C
# 48 C1=CC=CC2=C1C=C(C=C2)C#CC#CC3=CC4=C(C=C3)C=CC=C4
# 34 CC1=CC=C(C=C1)C#CC#CC2=CC=C(C=C2)C
# 34 C1=CC=C(C=C1)OCC#CC#CCOC2=CC=CC=C2
# 28 C1CCC(C1)(C#CC#CC2(CCCC2)O)O
# 14 C#CC1=CC=CC=C1
# 69 CC(=CCCC(=CC=CC(=CC=CC(=CC=CC=C(C)C=CC=C(C)C=CC=C(C)CCC=C(C)C)C)C)C)C
# 144 CCCCCC(CC)CC1=CC(=C(C=C1C#CC2=CC(=CC(=C2)C#CC3=CC(=C(C=C3CC(CC)CCCCC)C#C)CC(CC)CCCCC)C#CC4=CC(=C(C=C4CC(CC)CCCCC)C#C)CC(CC)CCCCC)CC(CC)CCCCC)C#C
# 30 C1=CC=C(C=C1)C#CC#CC2=CC=CC=C2

# %%
preprocess_data(filename_in='../data/getter_smiles_KP_V2',starting_point='random', min_len=14, max_len=74,augmentation=10)
#preprocess_data(filename_in='../data/SMILES_BIMODAL_FBRNN_fixed')
# Out:
# 15
# Pre-processing of "../data/getter_smiles_KP_V1" started.
#  invalid SMILES - removed.
#  duplicate SMILES - removed.
#  salts - removed.
#  stereochemistry - removed.
#  canonicalized SMILES.
# BIMODAL_random 74
# (13,)
# 13
# Data processed saved

# %%
df = pd.read_csv('../data/getter_smiles_KP_V2_BIMODAL_random_aug_10.csv', header=None)
mz = 0
for i in range(df.shape[0]):
    for j in range(df.shape[1]):
        print(len(df.iloc[i,j]))
# Out:
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 151

# %%
a = [1,2,3]
np.shape(a)
# Out:
# (3,)

# %%
data = pd.read_csv('../data/getter_smiles_KP_V1.csv', header=None)
data['LEN'] = [len(s) for s in data.iloc[:, 0]]
data[data.LEN<=77]
# Out:
#                                                     0  LEN
# 0                  C1=CC=C(C=C1)OCC#CC#CCOC2=CC=CC=C2   34
# 1                      C1=CC=C(C=C1)C#CC#CC2=CC=CC=C2   30
# 2                        C1CCC(C1)(C#CC#CC2(CCCC2)O)O   28
# 3         C1=CC=C(C=C1)C#CC2=CC=C(C=C2)C#CC3=CC=CC=C3   43
# 4                                      C#CC1=CC=CC=C1   14
# 5   CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC=CC=C(C)C=CC=...   73
# 6   CC(=CCCC(=CC=CC(=CC=CC(=CC=CC=C(C)C=CC=C(C)C=C...   69
# 8   C1=CC=C(C=C1)C2=CC=C(C=C2)C#CC#CC3=CC=C(C=C3)C...   56
# 9    C1=CC=CC2=C1C=C(C=C2)C#CC#CC3=CC4=C(C=C3)C=CC=C4   48
# 10             C1=CC(=CC=C1CCC#CC#CCCC2=CC=C(C=C2)C)C   38
# 11                 C1=CC=C(C=C1)CCC#CC#CCCC2=CC=CC=C2   34
# 12       C1(=CC(=CC(=C1C#CC#CC2=C(C=C(C=C2C)C)C)C)C)C   44
# 13           C1=C(C(=CC=C1C#CC#CC2=CC=C(C(=C2)C)C)C)C   40
# 14                 CC1=CC=C(C=C1)C#CC#CC2=CC=C(C=C2)C   34
